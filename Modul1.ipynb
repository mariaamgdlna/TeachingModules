# %% [markdown]
# ## Soal 1
# 1. Buatlah program yang berisikan:
# - `Integer = 10`
# - `Float = 3.14`
# - `Teks = “Halo, ini adalah string”`
# - `Benar = True`

# %%
Integer = 10
Float   = 3/14
Teks    = "Halo, ini adalah string”"
Benar   = True

# %% [markdown]
# ## Soal 2
# Diberikan statement berikut. Tampilkan tipe data tiap value.
#
# ```python
# value1 = 99
# value2 = 45.9
# value3 = 7.0
# value4 = 7
# value5 = 'abc'
# ```

# %%
value1 = 99
print('value1:', type(value1))

value2 = 45.9
print('value2:', type(value2))

value3 = 7.0
print('value3:', type(value3))

value4 = 7
print('value4:', type(value4))

value5 = 'abc'
print('value5:', type(value5))
# Out:
# value1: <class 'int'>
# value2: <class 'float'>
# value3: <class 'float'>
# value4: <class 'int'>
# value5: <class 'str'>

# %% [markdown]
# ## Soal 3
# Buatlah:
# - list daftar angka:  `1, 2, 3, 4, 5`
# - set daftar angka:  `1, 2, 3, 4, 5`
# - tuple daftar angka:  `1, 2, 3, 4, 5`

# %%
LIST  = [1, 2, 3, 4, 5]
SET   = {1, 2, 3, 4, 5}
TUPLE = (1, 2, 3, 4, 5)

# %% [markdown]
# # Soal 4
# Buat dictionary berikut:
#
# | Nama  | Usia | Jurusan     |
# | ----- | ---- | ----------- |
# | John  | 21   | Informatika |
# | Billy | 20   | Biomedik    |

# %%
data = {}
data['Nama']   = ['John', 'Billy'] 
data['Usia']   = [21, 20] 
data['Juruan'] = ['Informatika', 'Biomedik'] 

data
# Out:
# {'Nama': ['John', 'Billy'],
#  'Usia': [21, 20],
#  'Juruan': ['Informatika', 'Biomedik']}

# %% [markdown]
# # Soal 5
# Jika diketahui `x=3`, berapakah `x+=1` dan `x*=2`?

# %%
x = 3
x+=1
x
# Out:
# 4

# %%
x = 3
x*=2
x
# Out:
# 6

# %% [markdown]
# # Soal 6
# Diketahui `y = 2.5`, apakah tipe data dari `y`? Dan berapa `y+1`, `y*2`, `y**2`?

# %%
y = 2.5
type(y)
# Out:
# float

# %%
print(y+1)
print(y*2)
print(y**2)
# Out:
# 3.5
# 5.0
# 6.25

# %% [markdown]
# # Soal 7
# Diketahui `t `dan `f `masing-masing adalah `True` dan `False`.

# %%
t = True
f = False

# %% [markdown]
# Apakah tipe data `t` dan `f`?

# %%
print(type(t))
print(type(f))
# Out:
# <class 'bool'>
# <class 'bool'>

# %% [markdown]
# Tunjukkan `t` tidak sama dengan `f`.

# %%
t == f # apakah t = f?
# Out:
# False

# %% [markdown]
# Lalu, apakah hasil:
# 	- `t AND f` ,
# 	- `t OR f`
# 	- `not t`

# %%
print(t and f)
print(t or f)
print(not t)
# Out:
# False
# True
# False

# %% [markdown]
# # Soal 8
# Jika diketahui `z = 1e-3`, apakah tipe data dari `z`? Dan berapa `z+1`, `z*2`, `z**2`?

# %%
z = 1e-3
print(type(z))
print(z+1)
print(z*2)
print(z**2)
# Out:
# <class 'float'>
# 1.001
# 0.002
# 1e-06

# %% [markdown]
# # Soal 9
# Dengan menggunakan percabangan dan perulangan serta berbagai operator yang telah dipelajari pada Modul 1, buatlah program sederhana yang dapat menyediakan solusi pecahan uang.  Pecahan yang digunakan adalah: Rp. 50, Rp. 100, Rp. 200, Rp. 500, Rp. 1000, Rp. 2.000, Rp. 5.000, Rp. 10.000, Rp. 20.000, Rp. 50.000, dan Rp.100.000. **Pecahan yang diprioritaskan adalah pecahan yang lebih besar**. Gunakan template berikut:
#
# 	```python
# 	nilai = 1750 # sebagai contoh
#
# 	n50   = 0
# 	n100  = 0
# 	n200  = 0
# 	n500  = 0
# 	n1k   = 0
# 	n2k   = 0
# 	n5k   = 0
# 	n10k  = 0
# 	n20k  = 0
# 	n50k  = 0
# 	n100k = 0
#
# 	#
# 	# Ketik program Anda di sini
# 	#
#
# 	# Tampilkan hasil
# 	print('Nilai = ', nilai)
# 	print('\n')
# 	print("Pecahan 50 =", n50)
# 	print("Pecahan 100 =", n100)
# 	print("Pecahan 200 =", n200)
# 	print("Pecahan 500 =", n500)
# 	print("Pecahan 1000 =", n1k)
# 	print("Pecahan 2000 =", n2k)
# 	print("Pecahan 5000 =", n5k)
# 	print("Pecahan 10000 =", n10k)
# 	print("Pecahan 20000 =", n20k)
# 	print("Pecahan 50000 =", n50k)
# 	print("Pecahan 100000 =", n100k)
# 	print('\n')
# 	```

# %%
nilai = 14750

tersisa = nilai

n100k = tersisa // 100000
tersisa = tersisa % 100000

n50k = tersisa // 50000
tersisa = tersisa % 50000

n20k = tersisa // 20000
tersisa = tersisa % 20000

n10k = tersisa // 10000
tersisa = tersisa % 10000

n5k = tersisa // 5000
tersisa = tersisa % 5000

n2k = tersisa // 2000
tersisa = tersisa % 2000

n1k = tersisa // 1000
tersisa = tersisa % 1000

n500 = tersisa // 500
tersisa = tersisa % 500

n200 = tersisa // 200
tersisa = tersisa % 200

n100 = tersisa // 100
tersisa = tersisa % 100

n50 = tersisa // 50
tersisa = tersisa % 50

# Tampilkan hasil
print('Nilai = ', nilai)
print('\n')
print("Pecahan 50       =", n50)
print("Pecahan 100      =", n100)
print("Pecahan 200      =", n200)
print("Pecahan 500      =", n500)
print("Pecahan 1000     =", n1k)
print("Pecahan 2000     =", n2k)
print("Pecahan 5000     =", n5k)
print("Pecahan 10000    =", n10k)
print("Pecahan 20000    =", n20k)
print("Pecahan 50000    =", n50k)
print("Pecahan 100000   =", n100k)
print('\n')
# Out:
# Nilai =  14750
#
#
# Pecahan 50       = 1
# Pecahan 100      = 0
# Pecahan 200      = 1
# Pecahan 500      = 1
# Pecahan 1000     = 0
# Pecahan 2000     = 2
# Pecahan 5000     = 0
# Pecahan 10000    = 1
# Pecahan 20000    = 0
# Pecahan 50000    = 0
# Pecahan 100000   = 0
